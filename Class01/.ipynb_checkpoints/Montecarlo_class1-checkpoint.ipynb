# %% [markdown]
# # Monte Carlo Simulations
#
# The Monte Carlo simulations are different methods to perform numerical calculation, better to be understood as "experimental" calculations.
#
# The name "Monte Carlo" were first used by Nicholas Metropolis, John von Neumann and Stanislav Ulman when they were working in the Manhattan Project at Los Alamos during World War II.
#
# The idea behind this method is that knowing some properties of a system, let's say statistical properties, we can use them to make predictions. However, this predictions' accuracy depend on the big number theorems. So to have good prediction we need a sufficiently big amount of numbers, and they should be random.

# %% [markdown]
# # Using Probability to solve a problem
# ## Buffon's Needle
#
# Lets imaging a plane surface with parallel lines, all separated by the same distance $D$, and lets imaging we drop a needle of length $L$ (Shorter than $D$).
# What is the probability of a needle crossing one line?
#
# We know that the center of the needle can be between 0 and $D$, and that the angle the needle is forming with the lines is $\theta$ between 0 and $2\pi$.
#
# Buffon showed that the probability of the needle intersecting one of the lines is $2D/\pi L$. By randomly tossing lots of needles on this surface we can count the number of crossings and estimate the probability by know the proportion of needles that crosses the lines, lets call it $f$. From here, we can estimate the value of $\pi$ by the equation:
#
# $$ \pi \approx \frac{2L}{fD}$$

# %%
import numpy as np
from numpy.random import rand
import matplotlib.pyplot as plt

# Distance from line to line
D = 5
# Lenght of the needles
L = 3
# Number of random number
N = 1000

# Center of the needles
centers = rand(N)*D
# Now we have to calculate the angle randomly

r = np.zeros(N)
yy = np.zeros(N)

# Just for ploting the distribution
x = []
xx = np.zeros(N)
y = []

for i in range(N):
    R = 2
    while R>1:
        X = rand()
        Y = rand()
        R =np.sqrt(X**2 + Y**2)
        # just for showing the chosing criteria
        if R > 1:
            x.append(X)
            y.append(Y)
    r[i] = R
    yy[i] = Y
    xx[i] = X

# %%
# we want to see the distribution of the posible angles
# In orange are the accepted angles, inside the circle,
plt.scatter(x,y)
plt.scatter(xx,yy)
plt.show()

# %%
# we want to know how manky steps where not used
len(x)
# Out:
# 254

# %%
# Now we calculate the probability
deltay = (L/2)*yy/r

hits = (deltay>=centers) +(deltay>= D-centers)

f = np.mean(hits)
print('The probability is: '+str(f))
# Theroetical probability
Ptheo = (2*L)/(np.pi*D)
Pi_approx = (2*L)/(f*D)

print('The theoretical probability is: '+str(Ptheo))
print('Pi ='+str(Pi_approx))
# Out:
# The probability is: 0.397
# The theoretical probability is: 0.38197186342054884
# Pi =3.022670025188917

# %%
Pi_approx
# Out:
# np.float64(3.022670025188917)

# %% [markdown]
# We can see that our result is not really accurate, we may ask the questions: How confident can we be in our result for a given number of trials? How many trials do we need to attain a specific level of confidence in the result?
#
# This example is good to identify the important parts of a Monte Carlo simulation.
# 1. Calculations model of the system of interest.
# 2. Data required by the model.
# 3. Simulation "Wrapper", this is the process of looping through the model calculations, selecting different data values from the statistical distributions and recalculating the corresponding parameter of interest.

# %% [markdown]
# ## Precision
#
# An important part of the model is the determination of the precision associated with the result, or the degree of confidence we have in it. To do this we need many samples, or trials, in each of which we obtain an estimate of $\pi$.
#
# One way of getting more estimates is simply to run the program many times, each with a different set of random numbers, recording the resulting estimate each time. For a program as small as this doing it does not represent a challenge, however with more elaborated simulation this may require very powerful computers.

# %%
def Buffon_Monte_Carlo(N=1000):
    # Constants
    D = 5
    L = 3
    # Variables
    centers = rand(N)*D
    r = np.zeros(N)
    yy = np.zeros(N)
    # Monte Carlo loop
    for i in range(N):
        R = 2
        while R>1:
            X = rand()
            Y = rand()
            R =np.sqrt(X**2 + Y**2)
        r[i] = R
        yy[i] = Y
    # Now we calculate the probability
    deltay = (L/2)*yy/r
    hits = (deltay>=centers) +(deltay>= D-centers)
    f = np.mean(hits)
    Pi_approx = (2*L)/(f*D)
    return(Pi_approx)

# %%
# Showing presition depending on number of needles
results = []
pi_approx = []
i = 1000
while i < 2000:
    results.append(i)
    pi_approx.append(Buffon_Monte_Carlo(i))
    i+=1

plt.scatter(results,pi_approx,s=10)
plt.axhline(y=3.1416, linestyle='--',color = 'orange')
plt.xlabel('Samples')
plt.ylabel(r"$\pi$ approximation")
plt.show()

# %% [markdown]
# Here we can see that we reach, so to speak, a "normal" precision very fast. Practically, there is no difference between 1000 and 2000 iterations. So it is necessary to explore a more statistical way to refine the precision. What we will do now is to run the program two thousand times, each time we will do one thousand iterations.
#
# ## Samples and Runs
#
# Samples are the number of "Monte-Carlo" loops or steps we will require our program to run, we can see that we are limited by the amount of operations our program need to run and the memory of the computer we are using.
#
# A run is literally to "run" the Monte-Carlo simulation program. With each run we can get a result. We can statistically make an estimation using the results of several runs.

# %%
# Showing presition for 2000 runs
results = []
pi_approx = []
for i in range(2000):
    results.append(i)
    pi_approx.append(Buffon_Monte_Carlo(1000))

plt.scatter(results,pi_approx,s=10)
plt.axhline(y=3.1416, linestyle='--',color = 'orange')
plt.xlabel('run')
plt.ylabel(r"$\pi$ approximation")
plt.show()

# %% [markdown]
# Now we can generate a histogram of these results to better understand what is happening here. We can see that the distribution of the results looks roughly normal. We should use the overall mean, $\mu$, standard deviation, $\sigma$, and standard error, $se$ from the run's average estimate of $\pi$.
#
# Central limit theorem:
# In probability theory, the central limit theorem (CLT) states that, under appropriate conditions, the distribution of a normalized version of the sample mean converges to a standard normal distribution. This holds even if the original variables themselves are not normally distributed. There are several versions of the CLT, each applying in the context of different conditions.

# %%
import scipy.stats as stats

plt.hist(pi_approx, bins=13, density=True)
plt.xlabel(r"$\pi$ approximation")

#Mean and stnd_dev
mean = np.mean(pi_approx)
stnd_dv = np.std(pi_approx)

xmin, xmax = plt.xlim()
x = np.linspace(xmin,xmax,100)
p = stats.norm.pdf(x,mean,stnd_dv)
plt.plot(x,p)
plt.show()

print('mean ='+str(mean)+'  Standar deviation ='+str(stnd_dv))
# Out:
# mean =3.145879191366402  Standar deviation =0.13087660417876681

# %% [markdown]
# ### Task 1
# Picture $n$ bins and $n$ balls. Construct a Monte-Carlo simulation program that randomly scatters the $n$ balls into the bins.
# - Count the number of bins that don't contain any balls, $n_0$.
# - Plot the ratio $n/n_0$ as a function of $n$
# - To what constant does the ratio seem to be trying for?

# %% [markdown]
# # Using Random Numbers to Solve Integrals
#
# We see in the previews example that using random numbers we can plot dots until we fill the area of a square, we can try to use this property to solve an integral by relating the ratio of points below and above the function we want to integrate and the area of the numbers we are sampling. (Let's remember we must know this area for the model to work)
#
# First, let's try to know the area covered by the $\sin x$, from 0 to $\pi$.
#
# If we randomly put points in the rectangular area from 0 to $\pi$ in the $x$ axis and from 0 to 1 in the $y$ axis, we have a rectangle of area $\pi$. Then the area under the curve should be estimated:
#
# $$A = \frac{\text{points inside}}{\text{total points}} \times \pi $$

# %%
# Lets define the function we want to integrate
N = 1000

x_in = []
x_out = []
y_in = []
y_out = []

i = 0
while i < N:
    x_temp = rand()*np.pi
    y_temp = rand()
    if y_temp <= np.sin(x_temp):
        y_in.append(y_temp)
        x_in.append(x_temp)
        i += 1
    else:
        x_out.append(x_temp)
        y_out.append(y_temp)

(len(y_in)/(len(x_in)+len(x_out)))*np.pi
# Out:
# 2.008690954980686

# %% [markdown]
# This guives us an estimation of the area under the curve
#
# $$ \int_0^\pi \sin(x) d x \approx A$$

# %%
# We can take a graphical look about what is happening
# Lets plot the function
x = np.linspace(0,np.pi,100)
y = np.sin(x)

plt.plot(x,y)

# Lets plot the points
plt.scatter(x_out,y_out,s=5)
plt.scatter(x_in,y_in,s=5)
plt.show()

# %% [markdown]
# Now, let's try to use our new superpowers to solve more difficult situations.
# Consider the function:
#
# $$ f(x) = x^2 \sin(18x) + \pi x$$
#
# Maybe this is a mathematically simple integration to do, but graphically we can see what the Monte Carlo will do with it.
# Let's define the function and see what we are dealing with:

# %%
# Lets plot the function
def fu (x):
    y = (x**2)*np.sin(18*x)+np.pi*x
    return y
x = np.linspace(0,np.pi,100)
y = fu(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# Then the integral we will try to solve will be:
# $$ \int_0^\pi x^2 \sin(18x) + \pi x d x = \frac{1}{18}\pi^2 (9 \pi -1) \approx 14.955$$
#
# Now let's apply the same idea and verify if we need to do some changes:

# %%
N = 10000

x_in = []
x_out = []
y_in = []
y_out = []

i = 0
while i < N:
    x_temp = rand()*np.pi
    y_temp = rand()*18
    if y_temp <= fu(x_temp):
        y_in.append(y_temp)
        x_in.append(x_temp)
        i += 1
    else:
        x_out.append(x_temp)
        y_out.append(y_temp)

(len(y_in)/(len(x_in)+len(x_out)))*(np.pi*18)
# Out:
# 15.274754265043159

# %%
# Lets plot the points
plt.plot(x,y)
plt.scatter(x_out,y_out,s=5)
plt.scatter(x_in,y_in,s=5)
plt.show()

# %% [markdown]
# We can se clearly that we are generating way more points than we need, in this case is not relevant but with more complex problems we will need to be resourceful and efficient.
#
# ## Probability Distributions
#
# Some times to solve a problem in the most efficient way we need to know a prelimenar condition to the solution of the problem, this could be related to the probability of the solution to exist. In the case we are analizing now it is clear that the function only exist  in one half of the area that we are analizing. We can improve te program by changing the sampling method for the random number, this will be efectibly making them less random, this can create a new problem that is known as over fiting, we want to avoid this mistake. For now we will only learn how to make new random number distributions.
#
# Lets learn how to make random numbers in a pattern:

# %%
def m (x):
    y = (18/3)*x
    return y

z = m(x)

plt.plot(x,y)
plt.plot(x,z)

# %%
# now for each pair of numbers we will have to generate:
def Random_slope():
    """
    This func return a pair of random numbers below the slope
    """
    x_temp = rand()*np.pi
    y_temp = rand()*m(x_temp)
    return x_temp, y_temp

# %%
x_rand = []
y_rand = []
for i in range(100):
    xt,yt = Random_slope()
    x_rand.append(xt)
    y_rand.append(yt)

plt.scatter(x_rand,y_rand,s=5)

# %%
N = 10000

x_in = []
x_out = []
y_in = []
y_out = []

i = 0
while i < N:
    x_temp,y_temp = Random_slope()
    if y_temp <= fu(x_temp):
        y_in.append(y_temp)
        x_in.append(x_temp)
        i += 1
    else:
        x_out.append(x_temp)
        y_out.append(y_temp)

(len(y_in)/(len(x_in)+len(x_out)))*(((18/3)*np.pi**2)/2)
# Out:
# 15.217563449282045

# %%
# Lets plot the points
plt.plot(x,y)
plt.scatter(x_out,y_out,s=5)
plt.scatter(x_in,y_in,s=5)
plt.show()

# %% [markdown]
# This approach is more efficient, however wrong. The idea is good, but need to be improved.
#
# The problem we are facing here is the generation of good random numbers. We can see in the plot that the numbers are not uniformly distributed in the area under the line. We need to think on a better way to generate this random numbers.
#
# ## Metropolis Algorithm
#
# We can think abouth the Metropolis Algorithm as a simplified Monte Carlo calculation. The basic idea is that we will generate random numbers and we will only alow those that are permited by the probability function. Knowing the probability then, sampling a very large number of random numbers we will have a good aproximatino of the desire distribution.

# %%
def Slope (x):
    return (18/3)*x
    
def Random_Triang():
    """
    This func return a pair of random numbers x y in a
    triangular ditribution of probability
    """
    x = 0
    p = 1
    while p > Slope(x):
        x = rand()*np.pi
        p = rand()*Slope(np.pi)
    y = Slope(x)*rand()
    return x,y

# %%
x_rand = []
y_rand = []
for i in range(1000):
    xt,yt = Random_Triang()
    x_rand.append(xt)
    y_rand.append(yt)

plt.scatter(x_rand,y_rand,s=5)

# %%
plt.hist(x_rand, bins=30, density=True)
plt.show()

# %% [markdown]
# Now let's try to do the integration again with the new function to generate the random numbers.

# %%
N = 10000

x_in = []
x_out = []
y_in = []
y_out = []

i = 0
while i < N:
    x_temp,y_temp = Random_Triang()
    if y_temp <= fu(x_temp):
        y_in.append(y_temp)
        x_in.append(x_temp)
        i += 1
    else:
        x_out.append(x_temp)
        y_out.append(y_temp)

(len(y_in)/(len(x_in)+len(x_out)))*(((18/3)*np.pi**2)/2)
# Out:
# 15.07577047009576

# %%
# Lets plot the points
plt.plot(x,y)
plt.scatter(x_out,y_out,s=5)
plt.scatter(x_in,y_in,s=5)
plt.show()

# %% [markdown]
# ## Task 2
#
# The adecuate choice of the random numbers used are different from problem to problem. The study of the efficency of the solutions is worth of our time before spending computational time of our machines. For the integral we just solve we proposed 3 different methods based on random number distributions. Each of these methods have its own complexity and computational dimention. For this 3 solutions:
# 1. Try to modify the code of each solution to make it more efficent.
# 2. Analize the amount of thimes the program is runing and not contributing to the result, this is calculate the ratio of points generated outside the area of interest.
# 3. Using the new functions, analize the results estatistical distribution, is it normal?
# 4. How the results distribution changes with the number of Samples?
# 5. What is the best method and why?

# %% [markdown]
# ## Optimisation
#
# We have seen how the idea of using random numbers is very usefull to finde the numerical solution of integrals. We can also try to use this idea to solve the inverse problem and use it to optimize a function, meaning to finding a minimun solution in a delimited area. There are many different forms to implement this method to solve this problem, we will try to understand two of them. Random walks and semi-random sampling.
